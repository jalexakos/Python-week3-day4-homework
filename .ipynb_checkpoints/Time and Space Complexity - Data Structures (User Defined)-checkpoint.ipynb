# %% [markdown]
# # Time/Space Complexity - Intro to Data Structures (User Defined)
#
# ### Topics to discuss today:
#
# <ul>
#     <li>Time and Space Complexity - What is it/How do we measure it</li>
#     <li>Asymptotic Analysis</li>
#     <li><strong>Data Structures</strong></li>
#     <li>Some of the popular sorting algorithms</li>
# </ul>
#
# ### Data Structures to discuss:
# - Arrays
# - Stacks
# - Queues
# - Linked Lists
#     - Singly Linked Lists
#     - Traversing A Linked List
#     - Finding a node in a linked list
#     - Adding to a linked list
# - Binary Search Trees
#     - Construction
#     - Traversal

# %% [markdown]
# ## Time and Space Complexity
#
# #### What is it?
#
# Time and space complexity is the measure of how much time a given action(function) will take to solve a problem. In the same fashion, we determine how much a given data structure will need in terms of memory allocation. A problem can have multiple solutions and finding the optimal solution for the problem needs to be analyzed in time and space.
#
# #### How do we measure Time and Space Complexity?
#
# In order to measure time and space complexity we use Asymptotic analysis. The reason for this is because we need a way to measure different algorithms (functions) based on the size of their inputs in a mathmatical way. For example, we could have a function that is computed as f(n) and another that is g(n^2). All things around the function staying constant, the only thing that changes is the size of the input. Below is the chart that shows the different Asymptotic analysis formats.

# %% [markdown]
# <table style="text-align:center;" class="table table-bordered">
# <tbody><tr>
# <td>constant</td>
# <td>−</td>
# <td>Ο(1)</td>
# </tr>
# <tr>
# <td>logarithmic</td>
# <td>−</td>
# <td>Ο(log n)</td>
# </tr>
# <tr>
# <td>linear</td>
# <td>−</td>
# <td>Ο(n)</td>
# </tr>
# <tr>
# <td>Linear Logarithmic</td>
# <td>−</td>
# <td>Ο(n log n)</td>
# </tr>
# <tr>
# <td>quadratic</td>
# <td>−</td>
# <td>Ο(n<sup>2</sup>)</td>
# </tr>
# <tr>
# <td>cubic</td>
# <td>−</td>
# <td>Ο(n<sup>3</sup>)</td>
# </tr>
# <tr>
# <td>polynomial</td>
# <td>−</td>
# <td>n<sup>Ο(1)</sup></td>
# </tr>
# <tr>
# <td>exponential</td>
# <td>−</td>
# <td>2<sup>Ο(n)</sup></td>
# </tr>
# </tbody></table>

# %% [markdown]
# ## Arrays

# %% [markdown]
# In python we benefit from the dynamic array which means the block of memory will expand as needed for the given input to the array. In traditional arrays (depending on the type of operating system) we will usually store our inputs in 4 or 8 consecutive blocks of memory. Below is a diagram of how that looks under the hood:
#
# <img src="http://www.mathcs.emory.edu/~cheung/Courses/170/Syllabus/09/FIGS/array02x.gif" style="height:250px; width:350px;">

# %% [markdown]
# ## Which in python looks like this:

# %%
array = [23,4,6,15,5,7,23] # Just added another element to this array
print(array)
# Out:
# [23, 4, 6, 15, 5, 7, 23]

# %% [markdown]
# ### Let's take a look at some of the time and space analysis of arrays

# %%
# Indexing an Array(list)
indexing = array[1] # Constant Time and Space - O(1)

# Searching through an array(list)
# Linear Time - O(n) Constant Space - O(1)
for i in array:
    print(i)
    
# Copying an array
# Linear Time - O(n) AND Linear Space - O(n)
copying = array[:] # It's copying the same numbers and taking up
# The same amount of space - hence why it's linear

# Setting an index in an array(list)
#Constant Time AND Constant Space O(1)
array[2] = 3 # Only impacts the same block of memory, nothing else
# Out:
# 23
# 4
# 6
# 15
# 5
# 7
# 23

# %% [markdown]
# ## Stacks and Queues (Review)
#
# ** Stacks ** as the name suggests is a data structure that allows for data to follow the Last In First Out priciple(LIFO). Think of a stack of pancakes for example. To get the first pancake you would  start with the top and go down.
#
# ##### Searching through a stack will be Linear Time O(n) - Constant Space O(1)
# ##### Selecting the last item will be done in Constant Time O(1) - Constant Space O(1)
# ##### Adding to the stack should take Constant Time O(1) - Constant Space O(1)
#
# ** Queues ** are similar but in this case follow the First In First Out principle(FIFO). Think of this as a line in a black friday sale. The first person camped out for the big screen tv is the first to get it.
#
# ##### Searching through a queue will be Linear Time O(n) - Constant Space O(1)
# ##### Selecting the first item will be done in Constant Time O(1) - Constant Space O(1)
# ##### Adding to the queue should take Constant Time O(1) - Constant Space O(1)

# %%
stack = []

stack.append(10)
stack.append(20)
stack.append(30)

#last_item = stack.pop()
#print(last_item) # Example of how stack works

# Searching a Stack - Linear Time O(n) - Constant Space O(1)
for i in stack:
    print(i)
    
queue = []
queue.append("Bob")
queue.append("Mary")
queue.append("Misty")

# first_item = queue.pop(0)
# print(first_item) # Bob was the first added, and is thus the first
# to leave

for i in queue:
    print(i)
# Out:
# 10
# 20
# 30
# Bob
# Mary
# Misty

# %% [markdown]
# ## Linked List (Data Structure)
#
# A linked list is created by using the node class. We create a Node object and create another class to use this node object. We pass the appropriate values thorugh the node object to point the to the next data elements.
#
# There are some advantages and disadvantages with this data structure. **Advantages** Linked Lists can save memory because they can be flexibile with memory management which saves memory. **Disadvantages** Finding or adding to the list requires traversing the entire list.

# %%
class LinkedListNode():
    def __init__(self,value):
        self.value = value
        self.next = None
        
    def traverseList(self):
        node = self
        while node != None:
            print(node.value)
            node = node.next
            
node1 = LinkedListNode("Mon")
node2 = LinkedListNode("Tues")
node3 = LinkedListNode('Wed')
node4 = LinkedListNode('Thurs')

node1.next = node2
node2.next = node3
node3.next = node4

print(node1.traverseList())
# Out:
# Mon
# Tues
# Wed
# Thurs
# None

# %%
# A Complete Implementation of a LinkedList

# 2 Components to this solution -- A Node Class and the LinkedList class

class Node():
    def __init__(self,value):
        self.value = value
        self.next = None
        
class LinkedList():
    def __init__(self):
        self.head = None
    
    def pushOn(self,new_value):
        new_node = Node(new_value)
        new_node.next = self.head
        self.head = new_node
    
    def insertAfter(self,prev_node,new_value):
        # Check if the previous node even exists
        if prev_node is None:
            print("The given previous node must not be empty!")
            return
        # IF the Node is not empty, then create a new node
        new_node = Node(new_value)
        
        # Update the previous node's next pointer to point to the new value
        new_node.next = prev_node.next
        
        # Update the previous node to point to the new node's value
        prev_node.next = new_node
        
    # This method will append a new node to the END of the LinkedList
    def append(self,new_value):
        # Create New Node with a new value
        new_node = Node(new_value)
        
        # Check if the LinkedList is empty
        # And if it is, make THIS new node the head node(beginning of the list)
        if self.head is None:
            self.head = new_node
            
        # BUT if the list is NOT empty - traverse to the end
        # and add the NEW value to the end of the list
        
        last = self.head
        
        # While last.next is not None > continue to loop until we find a None value
        while(last.next):
            last = last.next
        # Change current last node value to point to the NEW value
        last.next = new_node
    
    def traverse(self):
        temp = self.head
        # while temp is NOT None -> keep looping through the links until you reach a None Value
        while(temp):
            print(temp.value)
            temp = temp.next

weekdays_links = LinkedList()

# Insert a new day into the list
weekdays_links.pushOn("Mon")
weekdays_links.append("Tues")
weekdays_links.append("Thurs")
weekdays_links.insertAfter(weekdays_links.head.next,"Wed")
weekdays_links.traverse()
# Out:
# Mon
# Tues
# Wed
# Thurs

# %% [markdown]
# ## Binary Search Trees

# %%
class BST():
    def __init__(self,value):
        self.value = value # Current Value
        self.left = None
        self.right = None
        
    def insert(self,value):
        if value < self.value:
            if self.left is None:
                self.left = BST(value)
            else:
                self.left.insert(value)
        else:
            if self.right is None:
                self.right = BST(value)
            else:
                self.right.insert(value)
        return self
    
    def contains(self,value):
        """
            This method accepts an int for its value
            The value parameter is what we are looking for inside of the BST structure
        """
        if value < self.value: # if passed value is less than current value
            if self.left is None:
                return False
            else:
                return self.left.contains(value)
        elif value > self.value:
            if self.right is None:
                return False
            else:
                return self.right.contains(value)
        else:
            return True
        
        
    def getMinValue(self):
        if self.left is None:
            return self.value
        else:
            return self.left.getMinValue()
        
    def getMaxValue(self):
        if self.right is None:
            return self.value
        else:
            return self.right.getMaxValue()
        
    def remove(self,value,parent=None):
        if value < self.value:
            if self.left is not None:
                self.left.remove(value,self)
        elif value > self.value:
            if self.right is not None:
                self.right.remove(value,self)
        else:
            if self.left is not None and self.right is not None:
                self.value = self.right.getMinValue()
                self.right.remove(self.value,self)
            elif parent is None:
                if self.left is not None:
                    self.value = self.left.value
                    self.right = self.left.right
                    self.left = self.left.left
                elif self.right is not None:
                    self.value = self.right.value
                    self.left = self.right.left
                    self.right = self.right.right
                else:
                    self.value = None
            elif parent.left == self:
                parent.left = self.left if self.left is not None else self.right
            elif parent.right == self:
                parent.right = self.left if self.left is not None else self.right
        return self
    
bst_example = BST(39)
bst_example.insert(40)
bst_example.insert(50)
bst_example.insert(50)
bst_example.insert(50)
bst_example.insert(60)

print(bst_example.getMaxValue())
print(bst_example.contains(50))
print(bst_example.contains(44))
bst_example.remove(40)
print(bst_example.contains(40))
bst_example.remove(50)
print(bst_example.contains(50))
# Out:
# 60
# True
# False
# False
# True

# %% [markdown]
# # Homework

# %% [markdown]
# #### Problem 1: Linked Lists
#
# Using the above examples as a guide, create your own interpretation of the a Linked List class. You can not use the code above exactly, but again it can be used as a guide. This problem requires you to think about how a linked list works and create one using your own logic.
#
# *Remember* A Linked List is a list of Nodes that point to the next node in the chain. The first Node starts out as Empty(None) and each node after points to the next.
#
# Your Linked List should have a traverse method and have the ability to add a new node

# %%
# Updating books in a bookshelf
# They all stay in a very large shelf, but get moved to the left or right
# I am using this concept to help me visual a linked list - it's not perfect, but it's a good example

class Book():
    def __init__(self,title):
        self.title = title
        self.next = None

class Bookshelf():
    def __init__(self):
        self.current = None
    
    # I am calling this one need to read, because I'm imagining that I'm saying, "Wow, this looks really good.
    # I need to read this ASAP!"
    def needToRead(self,new_title):
        new_book = Book(new_title)
        new_book.next = self.current
        self.current = new_book
        
    def squeezeAfter(self,prev_book,new_title):
        if prev_book is None:
            print("No need to squeeze it here, we got space!")
            return
        # Creating the book
        new_book = Book(new_title)
        
        # Moving the next book to come after the new one, rather than the previous one
        new_book.next = prev_book.next
        
        # Update the previous one to come before the new boo
        prev_book.next = new_book
        
    
    # Add to the end of the bookshelf - I want to read, but not desparately 
    def putOnEnd(self,new_title):
        new_book = Book(new_title)
        
        if self.current is None:
            self.current = new_book
        
        last = self.current
        # follow the shelf until there's an empty space at the end
        while(last.next):
            last = last.next
            
        last.next = new_book
        
    def scanShelf(self):
        viewing = self.current
        while(viewing):
            print(viewing.title)
            viewing = viewing.next
        print("\n")

bedside_table = Bookshelf()

bedside_table.needToRead("The Count of Monte Cristo")
bedside_table.putOnEnd("How To Make Friends and Influence People")
bedside_table.putOnEnd("John Adams")
bedside_table.putOnEnd("A Brief History of Thought")
# Now I want to squeeze "A Tale of Two Cities" in 
# right after "The Count of Monte Cristo"
bedside_table.squeezeAfter(bedside_table.current,"A Tale of Two Cities")
bedside_table.scanShelf()
bedside_table.needToRead("Sundiata: An Epic of Old Mali")
# I am not sure if this will work, but I'm trying to squeeze "HomeGoing" in after
# "How To Make Friends and Influence People"
bedside_table.squeezeAfter(bedside_table.current.next.next.next, "HomeGoing")
bedside_table.scanShelf()
bedside_table.needToRead("Their Eyes Were Watching God")
bedside_table.scanShelf()

# The interesting thing to track here is the terminology, and how things impact one another. I intentionally tried
# to change most of the words from the example above, to track how the different component pieces interacted.
# It made certain things more difficult, but I actually think it helped me see how things ultimately flow.
# Out:
# The Count of Monte Cristo
# A Tale of Two Cities
# How To Make Friends and Influence People
# John Adams
# A Brief History of Thought
#
#
# Sundiata: An Epic of Old Mali
# The Count of Monte Cristo
# A Tale of Two Cities
# How To Make Friends and Influence People
# HomeGoing
# John Adams
# A Brief History of Thought
#
#
# Their Eyes Were Watching God
# Sundiata: An Epic of Old Mali
# The Count of Monte Cristo
# A Tale of Two Cities
# How To Make Friends and Influence People
# HomeGoing
# John Adams
# A Brief History of Thought

# %% [markdown]
# #### Problem 2: Binary Search Tree
#
# Using the above examples as a guide, create your own interpretation of the a Binary Search Tree class. You can not use the code above exactly, but again it can be used as a guide. This problem requires you to think about how a Binary Search Tree works and create one using your own logic.
#
# *Remember* Binary Search Trees start with a head node and each node to the left of that will be smaller, each node to the right of it will be greater. The far left node should be the lowest number(if one exists) that is available. The far right node (if one exists) should be the greatest number

# %%
# Goals record in the Premier League
# Each time a player finishes a season, the goal numbers are added to the search tree 
# We would remove a record if it came out that the player had used PEDs (hypothetically, not real)
# I am working from this top 10 list: https://www.sportskeeda.com/football/most-goals-in-premier-league-season
# I will try to enter them based on chronology

class GoalCount():
    def __init__(self,goals):
        self.goals = goals # current record
        self.fewer = None
        self.greater = None
    
    # After a new season where someone has a great season
    def newScorer(self,goals):
        if goals < self.goals:
            if self.fewer is None:
                self.fewer = GoalCount(goals)
            else:
                self.fewer.newScorer(goals)
        else:
            if self.greater is None:
                self.greater = GoalCount(goals)
            else:
                self.greater.newScorer(goals)
        return self
    
    # Imagining friends debating the record, so they "check the books"
    def checkTheBooks(self,goals):
        """
            This method accepts an integer for its "goals" input
            The goals parameter is what we're searching for in the record books
        """
        if goals < self.goals:
            if self.fewer is None:
                return False
            else:
                return self.fewer.checkTheBooks(goals)
        elif goals > self.goals:
            if self.greater is None:
                return False
            else:
                return self.greater.checkTheBooks(goals)
        else:
            return True
    
    # Because we want to see who's bottom of the list
    def leastGoals(self):
        if self.fewer is None:
            return self.goals
        else:
            return self.fewer.leastGoals()
    
    # "If you're not first, you're last!"
    def mostGoals(self):
        if self.greater is None:
            return self.goals
        else:
            return self.greater.mostGoals()
    
    def scandal(self,goals,forebearer = None):
        if goals < self.goals:
            if self.fewer is not None:
                self.fewer.scandal(goals,self)
        elif goals > self.goals:
            if self.greater is not None:
                self.greater.scandal(goals,self)
        else:
            if self.fewer is not None and self.greater is not None:
                self.goals = self.greater.leastGoals()
                self.greater.remove(self,goals,self)
            elif forebearer is None:
                if self.fewer is not None:
                    self.goals = self.fewer.goals
                    self.greater = self.fewer.greater
                    self.fewer = self.fewer.fewer
                elif self.greater is not None:
                    self.goals = self.greater.goals
                    self.fewer = self.greater.fewer
                    self.greater = self.greater.greater
                else:
                    self.goals = None
            elif forebearer.fewer == self:
                forebearer.fewer = self.fewer if self.fewer is not None else self.greater
            elif forebearer.greater == self:
                forebearer.greater = self.fewer if self.fewer is not None else self.greater
        return self
    
prem_goals_scored = GoalCount(31) # Alan Shearer, Newcastle Legend
prem_goals_scored.newScorer(30) # Kevin Phillips...? Whoever that is
prem_goals_scored.checkTheBooks(32) # No one has scored 32... yet!
prem_goals_scored.newScorer(30) # Thierry Henry
prem_goals_scored.mostGoals() # Returned 31 at this point
prem_goals_scored.newScorer(31) # CR7. Enough said
prem_goals_scored.newScorer(29) # Drogba!
prem_goals_scored.leastGoals()
prem_goals_scored.newScorer(30) # RVP
prem_goals_scored.newScorer(31) # Luis Suarez, dangerous on the pitch in more ways than one.
prem_goals_scored.newScorer(29) # Kane x1
prem_goals_scored.newScorer(30) # Kane x2
prem_goals_scored.checkTheBooks(31) # True! Three times, I think
prem_goals_scored.mostGoals() # 31... for now
prem_goals_scored.newScorer(32) # Mo Salah, you little dancer!
prem_goals_scored.newScorer(34) # My record!!!
prem_goals_scored.scandal(34) # ...because I was on HGH
prem_goals_scored.mostGoals()


# Harder to come up with an example for practice, just because you always have to enter an integer. I tried to
# make it challenging by again changing the names and seeing if I could follow the logic. I think my language
# changes actually make it a little more intuitive. However, that doesn't mean it's easier!
# This was more challenging than the linked list. I think I understand pretty much all of it, except the 
# "remove"/"scandal" function. I need to draw out the logic more, so I understand how things shift around.
# Out:
# 32
